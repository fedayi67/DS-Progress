# %%
hello world # While writing two words, the console thinks as if it is a string,or 
# non-variable, that's why it gives the invalid syntax error in the word world
# not hello
# Out:
#   Cell In[4], line 1
#     hello world # While writing two words, the console thinks as if it is a string,
#           ^
# SyntaxError: invalid syntax

# %%
hello # when it is a single word, the console thinks of it as variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
print("Hello World")
# Out:
# Hello World

# %%
Print("Hello world") # Python is case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Print("Hello world")
#
# NameError: name 'Print' is not defined

# %%
"""We can write numbers of lines of strings between a couple of triple (') or (")
while we can write only one line of string in a couple of single (') or (")
"""
# Out:
# 'We can write numbers of lines of strings between a couple of triple (\') or (")\nwhile we can write only one line of string in a couple of single (\') or (")\n'

# %%
print('IF we open a string with a single quotation, we must end it with the same
      otherwise it'll give error, it'll keep looking for the next single quoatation
      until it finds one, and if not, it'll give error")
# Out:
#   Cell In[11], line 1
#     print('IF we open a string with a single quotation, we must end it with the same
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('I\'m an astronot') # we use \ to ignore the next quotataion here
# Out:
# I'm an astronot

# %%
print("I'm an astronot")
# Out:
# I'm an astronot

# %%
print("Hi I have been using python")
print("And it's awesome")
# Out:
# Hi I have been using python
# And it's awesome

# %%
print("""I have been using Python
 and it's awesome""")
# Out:
# I have been using Python
#  and it's awesome

# %%
print("""python is a"wesome""")
# Out:
# python is a"wesome

# %%
print("""""Hello world"""my name is ahmad""""") #the moment console sees it's 
first three " it keeps looking for the next triple " it doesn't even take the comment 
into account, it is still looking for the next triple "
And the moment it sees the next triple line like before my name is ahmad, it closes 
the string
# Out:
#   Cell In[21], line 1
#     print("""""Hello world"""my name is ahmad""""") #the moment console sees it's
#                                              ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 5)

# %%
print(""Hello wold"") # a double ' or " means, open and close, it doesn't care
# what comes after it 
print(''Merhaba dunya'')
# Out:
#   Cell In[22], line 1
#     print(""Hello wold"") # a double ' or " means, open and close, it doesn't care
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("""""Merhaba dunya""""") 
"""
here, one might wonder why it printed out a couple
double quotes, here what python did was:
1. It saw a three double quotes so it went looking for the next three double quotes
2. The first thing it came across was a couple double string, hence it's not a triple double quote so it interpret it as string
3. Next it intertret everything it came across as string until it saw the next triple double quotes
4. The moment it saw triple " quotes, it closed the string,
5. And at the end there is a couple " which actualy is an opening and closing quote
"""
# Out:
# ""Merhaba dunya
# '\nhere, one might wonder why it printed out a couple\ndouble quotes, here what python did was:\n1. It saw a three double quotes so it went looking for the next three double quotes\n2. The first thing it came across was a couple double string, hence it\'s not a triple double quote so it interpret it as string\n3. Next it intertret everything it came across as string until it saw the next triple double quotes\n4. The moment it saw triple " quotes, it closed the string,\n5. And at the end there is a couple " which actualy is an opening and closing quote\n'

# %%
# if we write the same statement in print, it'd come cleaner like :
print("""
here, one might wonder why it printed out a couple
double quotes, here what python did was:
1. It saw a three double quotes so it went looking for the next three double quotes
2. The first thing it came across was a couple double string, hence it's not a triple double quote so it interpret it as string
3. Next it intertret everything it came across as string until it saw the next triple double quotes
4. The moment it saw triple " quotes, it closed the string,
5. And at the end there is a couple " which actualy is an opening and closing quote
""")
# Out:
# here, one might wonder why it printed out a couple
# double quotes, here what python did was:
# 1. It saw a three double quotes so it went looking for the next three double quotes
# 2. The first thing it came across was a couple double string, hence it's not a triple double quote so it interpret it as string
# 3. Next it intertret everything it came across as string until it saw the next triple double quotes
# 4. The moment it saw triple " quotes, it closed the string,
# 5. And at the end there is a couple " which actualy is an opening and closing quote

# %%
# The number of # decides the size of a markdown, single # creates the biggest while ###### creates the smallest size of markdown

# %% [markdown]
# # One
# ## Two
# ### Three
# #### Four
# ##### Five
# ###### Six

# %% [markdown]
# ## PEP 8 Rules
# ##### Limit all lines to a maximum of 79 characters. For flowing long blocks of text with fewer structural restrictions (docstrings or comments), the line length should be limited to 72 characters.

# %% [markdown]
# ### Comments

# %%
3 + 5 
# We can write comments with the help of #  in python, it doesn't read as code, 
#it's for the user to read and comment and write  in order for himself and 
# #for others who use the code to further understand the steps and all
# Out:
# 8

# %%
# To write multiple lines of comments, we use # at the beginning of every line,
# if we use # with a code, then python doesn't execute even the code like :
# print("Hello World")

# %%
""" triple " or ' can be used as comments but the only difference would be 
 that python would print it out in the screen and could be store inside a 
 variable"""

# %% [markdown]
# #### Syntax
# ##### the set of rules that defines how a Python program will be written and interpreted

# %%
# Ex:
print(hello) 
# here we will take syntax error because it is not a defined variable, hence
# it has to be written inside "" to be string, it either has to fall into
# one of the categories above, so it doesn't follow the rules
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Ex:
# ----> 2 print(hello)
#       3 # here we will take syntax error because it is not a defined variable, hence
#       4 # it has to be written inside "" to be string, it either has to fall into
#       5 # one of the categories above, so it doesn't follow the rules
#
# NameError: name 'hello' is not defined

# %% [markdown]
# ### Data Types in Python

# %%
print("""
Text Type:	str
Numeric Types:	int, float, complex
Sequence Types:	list, tuple, range
Mapping Type:	dict
Set Types:	set, frozenset
Boolean Type:	bool
Binary Types:	bytes, bytearray, memoryview
None Type:	NoneType
""")
# Out:
# Text Type:	str
# Numeric Types:	int, float, complex
# Sequence Types:	list, tuple, range
# Mapping Type:	dict
# Set Types:	set, frozenset
# Boolean Type:	bool
# Binary Types:	bytes, bytearray, memoryview
# None Type:	NoneType

# %%
# In Python, the data type is set when you assign a value to a variable:

x = "Hello World"	# str	
x = 20	# int	
x = 20.5	# float	
x = 1j	# complex	
x = ["apple", "banana", "cherry"]	# list	
x = ("apple", "banana", "cherry")	# tuple	
x = range(6)	# range	
x = {"name" : "John", "age" : 36}	# dict	
x = {"apple", "banana", "cherry"}	# set	
x = frozenset({"apple", "banana", "cherry"})	# frozenset	
x = True	# bool

# %%
"Hello World!" # A String or str data type
# Out:
# 'Hello World!'

# %%
print(type("Hello world")) # we can do it directly
# Out:
# <class 'str'>

# %%
name7
# Out:
# 'Bilal'

# %%
print(type(name7)) # or even after storing in a variable,
# Out:
# <class 'str'>

# %%
age
# Out:
# 32

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print("3"+"5") # since it's a string, it doesn't add them up, it concatenates them
# the process of adding to strings together, or joining them up is called as concatenation
# Out:
# 35

# %%
type("3"+"5") # the type doesn't change, because it doesn't add them
# it concatenates em
# Out:
# str

# %%
print("5"*4) # in strings, when we multiply them by a number, it just concatenates
# the strings as many times as it is multiplied to
# Out:
# 5555

# %%
print("5"*"4") # cannot multiply by a string since it doesn't have a value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 print("5"*"4") # cannot multiply by a string since it doesn't have a value
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print("3" + 5) # we cannot use different operations with different data types such as this
# we can use addition only while concatenating two strings, and use multiplication while
# writing writing strings as many times as the integer it is multiplied to like:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 print("3" + 5) # we cannot use different operations with different data types such as this
#       2 # we can use addition only while concatenating two strings, and use multiplication while
#       3 # writing writing strings as many times as the integer it is multiplied to like:
#
# TypeError: can only concatenate str (not "int") to str

# %%
"Sedat" * 3
# Out:
# 'SedatSedatSedat'

# %%
"Sedat " * 3
# Out:
# 'Sedat Sedat Sedat '

# %%
2 * 3 # operation multiplication is done as they are both integers
# Out:
# 6

# %%
name7
# Out:
# 'Bilal'

# %%
print("name7" * 3) # here name7 is a string
# Out:
# name7name7name7

# %%
print(name7*3) # here name7 is a variable storing the value or string Bilal
# Out:
# BilalBilalBilal

# %%
pi_num
# Out:
# 3.14

# %%
type(pi_num)
# Out:
# float

# %%
pi_num
# Out:
# 3.14

# %%
pi_number = 3, 14 # it is a comma, it is separating 3 and 14 as two different elements

# %%
pi_number
# Out:
# (3, 14)

# %%
type(pi_number)
# Out:
# tuple

# %%
type("3.14")
# Out:
# str

# %%
name11
# Out:
# ('Berat', 'Advait')

# %%
type(name11)
# Out:
# tuple

# %%
type(False) # keep in mind that first letter of the booleans must be a capital
# Out:
# bool

# %%
type(false) # here python thinks of false as a variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 type(false) # here python thinks of false as a variable
#
# NameError: name 'false' is not defined

# %%
type(True)
# Out:
# bool

# %%
type("","") # type can take only one argument, not multiple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 type("","") # type can take only one argument, not multiple
#
# TypeError: type() takes 1 or 3 arguments

# %%
age = 50
bool(age) # boolean of something will be True, unless it is none or null or empty 
# or zero like the following:
# Out:
# True

# %%
print(bool(0))
print(bool(()))
print(bool(""))
print(bool([]))
print(bool({}))
print(bool(None))
# Out:
# False
# False
# False
# False
# False
# False

# %%
print("3" / 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 print("3" / 5)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
print("5" %  4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 print("5" %  4)
#
# TypeError: not all arguments converted during string formatting

# %% [markdown]
# ## Variables

# %%
 # Variables are containers for storing data values.
# Python has no command for declaring a variable.
# A variable is created the moment you first assign a value to it.
# it can store any type of data, from text type to None type
# let's declare a varablie to all the data types aboove we saw

# %%
# Variables do not need to be declared with any particular type, and can even change type after they have been set.
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %%
age = 32
# here age is the variable and 32 is the value assigned to it

# %%
name = "Ahmad Jawid"

# %%
# we can call the variable by simply calling it by name:
name
# Out:
# 'Ahmad Jawid'

# %%
# or by printing it's value like :
print(name)
# Out:
# Ahmad Jawid

# %%
name2 = ahmad # here ahmad either has to be another variable or a string data type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 name2 = ahmad # here ahmad either has to be another variable or a string data type
#
# NameError: name 'ahmad' is not defined

# %%
# String variables can be declared either by using single or double quotes:
x = "John"
print(x)
# Out:
# John

# %%
# is the same as
x = 'John'
print(x)
# Out:
# John

# %%
name3 = 'sedat" 
# both, opening and closing of the string literal has to be the same
# Out:
#   Cell In[66], line 1
#     name3 = 'sedat"
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name_3 = "Fedayi"

# %%
name_3 # while calling it by name, it shows the ' around the string showing
# that it's a string data type
# Out:
# 'Fedayi'

# %%
print(name_3) # but while printing it doesn't
# Out:
# Fedayi

# %%
name_4 = "Ahmad Jawid Fedayi"
name_4
# Out:
# 'Ahmad Jawid Fedayi'

# %%
print(name_4)
# Out:
# Ahmad Jawid Fedayi

# %%
# in the example above, python thinks that ahmad is a variable and is defined

# %%
# If you want to specify the data type of a variable, this can be done with casting.
x = str(3)    # x will be '3'
print(x)
y = int(3)    # y will be 3
print(y)
z = float(3)  # z will be 3.0
print(z)
# Out:
# 3
# 3
# 3.0

# %%
city = str(london) # even while casting, if we want to write a string inside the 
# function str, still we must include it inside the "" otherwise 
# python will think it's a declared variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 city = str(london) # even while casting, if we want to write a string inside the
#       2 # function str, still we must include it inside the "" otherwise
#       3 # python will think it's a declared variable
#
# NameError: name 'london' is not defined

# %%
city = str("London")
+city
# Out:
# 'London'

# %%
my_total_grades = float(65+98+76+84+97)

# %%
my_total_grades
# Out:
# 420.0

# %%
first_name = "Ahmad Jawid"
last_name = "Fedayi"

# %%
first_name # while calling multiple variables by name, we must remember
# that python will call the last variable it sees so we should always consider
# calling the variables with print
last_name
# Out:
# 'Fedayi'

# %%
print(first_name) # we don't have to include variables first_name and last_name
# inside the "" because it is  a variable not a string, although it stores a 
# string value but it doesn't mean we should include it inside the "", because it'll 
# print the name of the variable name not what it stores
print(last_name)
print("first_name")
print("last_name")
# Out:
# Ahmad Jawid
# Fedayi
# first_name
# last_name

# %%
pi_number = 3.14 # we should declare the variable however we see convenient
# and however we can remember it later on easily 
pi_num = 3.14

# %%
# and while adding or subtracting the variables it doesn't apply to the name
# of the variable but rather to the values it store
print(pi_number - pi_num)
print(pi_number + pi_num)
# Out:
# 0.0
# 6.28

# %% [markdown]
# ##### Type

# %%
# We can get the data type of a variable with the type() function.
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = "5555"
print(type(x)) # here we can clearly see that 5555 is written as string, inside the ""
# Out:
# <class 'str'>

# %%
x = 5555
print(type(x))
# Out:
# <class 'int'>

# %%
# Variable names are case-sensitive.
a = 4
A = "Sally"
#A will not overwrite a
print(a)
print(A)
# Out:
# 4
# Sally

# %%
"""
A variable can have a short name (like x and y) or a more descriptive name 
(age, carname, total_volume). Rules for Python variables:
- A variable name must start with a letter or the underscore character
- A variable name cannot start with a number
- A variable name can only contain alpha-numeric characters and 
underscores (A-z, 0-9, and _ )
- Variable names are case-sensitive (age, Age and AGE 
are three different variables)
- A variable name cannot be any of the Python keywords.
"""
# Out:
# '\nA variable can have a short name (like x and y) or a more descriptive name \n(age, carname, total_volume). Rules for Python variables:\n- A variable name must start with a letter or the underscore character\n- A variable name cannot start with a number\n- A variable name can only contain alpha-numeric characters and \nunderscores (A-z, 0-9, and _ )\n- Variable names are case-sensitive (age, Age and AGE \nare three different variables)\n- A variable name cannot be any of the Python keywords.\n'

# %%
# Legal variable names:
myvar = "Ahmad"
my_var = "Ahmad"
_my_var = "Ahmad"
myVar = "Ahmad"
MYVAR = "Ahmad"
myvar2 = "Ahmad"

# %%
# Illegal variable names:

2myvar = "John"
my-var = "John"
my var = "John"
# Out:
#   Cell In[49], line 3
#     2myvar = "John"
#     ^
# SyntaxError: invalid decimal literal

# %%
"""
Variable names with more than one word can be difficult to read.
There are several techniques you can use to make them more readable:

1. Camel Case
Each word, except the first, starts with a capital letter:
myVariableName = "Jawid"

2. Pascal Case
Each word starts with a capital letter:
MyVariableName = "Jawid"

3. Snake Case
Each word is separated by an underscore character:Jawid
my_variable_name = "Jawid"
"""
# Out:
# '\nVariable names with more than one word can be difficult to read.\nThere are several techniques you can use to make them more readable:\n\n1. Camel Case\nEach word, except the first, starts with a capital letter:\nmyVariableName = "Jawid"\n\n2. Pascal Case\nEach word starts with a capital letter:\nMyVariableName = "Jawid"\n\n3. Snake Case\nEach word is separated by an underscore character:Jawid\nmy_variable_name = "Jawid"\n'

# %%
# Assign Multiple Values
# 1. Many Values to Multiple Variables
# Python allows you to assign values to multiple variables in one line:

x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
#  in these types of examples, order is really important as:
name7,name8 = "Selim","Bilal"

# %%
name7
# Out:
# 'Selim'

# %%
name8
# Out:
# 'Bilal'

# %%
name8,name7 = "Selim","Bilal"

# %%
name8
# Out:
# 'Selim'

# %%
name7
# Out:
# 'Bilal'

# %%
name77,name88 = "Bilal","Selim"

# %%
name77
# Out:
# 'Bilal'

# %%
name88
# Out:
# 'Selim'

# %%
# while assigning value to two variables,we must assign to both, we cannot 
# assign to one and keep the other empty like:
nam_9,name_10 = "ozgur"
# If we want to assign a value to multiple variables,following is the way to do it:
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 3
#       1 # while assigning value to two variables,we must assign to both, we cannot
#       2 # assign to one and keep the other empty like:
# ----> 3 nam_9,name_10 = "ozgur"
#       4 # If we want to assign a value to multiple variables,following is the way to do it:
#
# ValueError: too many values to unpack (expected 2)

# %%
# 2. One Value to Multiple Variables
# And you can assign the same value to multiple variables in one line:

x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
x
# Out:
# 'Orange'

# %%
y
# Out:
# 'Orange'

# %%
my_age = 32 # we can take another variables value by simply assigning like:
your_age = 50
my_age = your_age
my_age
# Out:
# 50

# %%
# adn update it again, python would know the latest one 
my_age = 55

# %%
my_age
# Out:
# 55

# %%
name87 = "ahmad"
name87 = "fedayi"
name87
# Out:
# 'fedayi'

# %%
# we can store multiple values to one variable like : but the type would change to tuple
name11 = "Berat","Advait"

# %%
name11
# Out:
# ('Berat', 'Advait')

# %%
type(name11) # although it is storing multiple values, the type doesn't change
# Out:
# tuple

# %%
#Unpack a Collection
#If you have a collection of values in a list, tuple etc. 
#Python allows you to extract the values into variables. This is called unpacking.

fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# these we can clearly understand in the list, tuple sections
# Out:
# apple
# banana
# cherry

# %%
# Global Variables
# Variables that are created outside of a function 
# (as in all of the examples above) are known as global variables.
# Global variables can be used by everyone, both inside of functions and outside.

# Create a variable outside of a function, and use it inside the function

x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
# If you create a variable with the same name inside a function, 
#this variable will be local, and can only be used inside the function. 
#The global variable with the same name will remain as it was, global and 
#with the original value.
# Create a variable inside a function, with the same name as the global variable

x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
# The global Keyword
# Normally, when you create a variable inside a function, that variable is local, 
# and can only be used inside that function.
# To create a global variable inside a function, you can use the global keyword.

#If you use the global keyword, the variable belongs to the global scope:

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
# Also, use the global keyword if you want to change a global variable inside a function.
#To change the value of a global variable inside a function, 
#refer to the variable by using the global keyword:

x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
