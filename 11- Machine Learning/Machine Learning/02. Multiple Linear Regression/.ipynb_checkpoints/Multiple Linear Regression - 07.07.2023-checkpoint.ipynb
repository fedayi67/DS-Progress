# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

plt.rcParams["figure.figsize"] = (10, 6)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# y = b0 + b1*x1 - Simple Linear regression
#
# X1 = TV
#
# X2 = Radio
#
# X3 = NewsPaper
#
# y = b0 + b1 * x1 + b2 * x2 + b3 * x3

# %% [markdown]
# ## Read Dataset

# %%
df = pd.read_csv ("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(df); # a way to visualize missing values as matrix.

# %%
df.sort_values(by = "sales", ascending = False)
# Out:
#         TV  radio  newspaper  sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# ..     ...    ...        ...    ...
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 8      8.6    2.1        1.0    4.8
# 155    4.1   11.6        5.7    3.2
# 130    0.7   39.6        8.7    1.6
#
# [200 rows x 4 columns]

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %% [markdown]
# ## Outlier için örnek

# %%
print(np.mean([100, 110, 120, 115]))
print(np.std([100, 110, 120, 115]))
# Out:
# 111.25
# 7.39509972887452

# %%
print(np.mean([100, 110, 120, 700]))
print(np.std([100, 110, 120, 700]))
# Out:
# 257.5
# 255.57533136044253

# %%
print(np.mean([100, 110, 120, 900]))
print(np.std([100, 110, 120, 900]))
# Out:
# 307.5
# 342.153109002388

# %%
sns.pairplot(df);

# %%
sns.heatmap(df.corr(), annot = True); # if there is no correlation there is no linearity.

# %%
from scipy.stats import skew

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in df.drop(columns = "sales").columns:
    print(i, skew(df[i]))
# Out:
# TV -0.06932836662244649
# radio 0.0934668451108453
# newspaper 0.8879959753085498

# %%
for j in df.drop(columns = "sales").columns:
    g = sns.distplot(df[j], color= "b", label= "Skewness : %.2f"%(df[j].skew()))
    g = g.legend(loc= "best")
    plt.show()

# %% [markdown]
# if there is 0.8 correlation among independent variable or features there might be multicollinearity but we accept until 0.9
#
# normal distributions gives us a better score

# %%
sns.heatmap(df.corr(), annot = True);

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Tv- sales : Kuvvetli doğrusal ilişiki
# Radio-sales: Orta Kuvvetli doğrusal ilişiki
# Newspaper -sales : Çok düşük doğrusal ilişiki

# %% [markdown]
# ## Train - Test Split

# %% [markdown]
# Data 1000'e kadar (row 1000'e kadarsa) %70 Train, %30 Test (Train için En düşük bu olmalı)
#
# Data 1000 - 100.000 ler arasında ise %80-90 Train %20-10 Test
#
# Data 100.000 - 1.000.000 lar arasında ise %95 Train %5 Test
#
# Data milyonlar üzerinde ise %99 Train, %1 Test olarak bölünse iyi olur

# %%
X = df.drop(columns = "sales") # Features ve Target ayrıldı

y = df["sales"]

# %%
print(X, y)
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns] 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
# in order to get the same output, we all write the same number.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\ny Test features shape : {}".format
      (X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (140, 3)
# y Train features shape: (140,)
# X Test features shape : (60, 3)
# y Test features shape : (60,)

# %%
#Print("Train features shape: ", X_train.shape)
#Print("Train target shape: ", y_train.shape)
#Print("Test features shape: ", X_test.shape)
#Print("Test target shape: ", y_test.shape)

# %%
X_train
# Out:
#         TV  radio  newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [140 rows x 3 columns]

# %%
y_train
# Out:
# 169    15.0
# 97     15.5
# 31     11.9
# 12      9.2
# 35     12.8
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: sales, Length: 140, dtype: float64

# %% [markdown]
# Cross validation is a must to learn

# %% [markdown]
# ## Model Fitting and Compare Actual and Predicted Labels

# %%
from sklearn.linear_model import LinearRegression #as model olur fakat literatür bu şekilde fromla başlayan hiç bir syntax as ile devam etmez

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([16.5653963 , 21.18822792, 21.55107058, 10.88923816, 22.20231988,
#        13.35556872, 21.19692502,  7.35028523, 13.27547079, 15.12449511,
#         9.01443026,  6.52542825, 14.30205991,  8.97026042,  9.45679576,
#        12.00454351,  8.91549403, 16.15619251, 10.29582883, 18.72473553,
#        19.76821818, 13.77469028, 12.49638908, 21.53501762,  7.60860741,
#         5.6119801 , 20.91759483, 11.80627665,  9.08076637,  8.51412012,
#        12.17604891,  9.9691939 , 21.73008956, 12.77770578, 18.1011362 ,
#        20.07590796, 14.26202556, 20.93826535, 10.83938827,  4.38190607,
#         9.51332406, 12.40486324, 10.17045434,  8.09081363, 13.16388427,
#         5.2243552 ,  9.28893833, 14.09330719,  8.69024497, 11.66119763,
#        15.71848432, 11.63156862, 13.35360735, 11.1531472 ,  6.33636845,
#         9.76157954,  9.4195714 , 24.25516546,  7.69519137, 12.15317572])

# %%
model.coef_
# Out:
# array([0.04405928, 0.1992875 , 0.00688245])

# %%
model.intercept_
# Out:
# 2.708949092515912

# %% [markdown]
# y_pred = b3*TV + b2*radio + b1*newspaper + b0

# %%
sum(X_test.loc[95] * model.coef_) + model.intercept_
# Out:
# 16.565396297434837

# %%
my_dict = {"Actual": y_test, "pred":y_pred, "residual": y_test-y_pred}

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393
# 60      8.1   5.611980  2.488020
# 84     21.7  20.917595  0.782405
# 67     13.4  11.806277  1.593723
# 125    10.6   9.080766  1.519234
# 132     5.7   8.514120 -2.814120
# 9      10.6  12.176049 -1.576049
# 18     11.3   9.969194  1.330806
# 55     23.7  21.730090  1.969910
# 75      8.7  12.777706 -4.077706
# 150    16.1  18.101136 -2.001136
# 104    20.7  20.075908  0.624092
# 135    11.6  14.262026 -2.662026
# 137    20.8  20.938265 -0.138265
# 164    11.9  10.839388  1.060612
# 76      6.9   4.381906  2.518094
# 79     11.0   9.513324  1.486676
# 197    12.8  12.404863  0.395137
# 38     10.1  10.170454 -0.070454
# 24      9.7   8.090814  1.609186
# 122    11.6  13.163884 -1.563884
# 195     7.6   5.224355  2.375645
# 29     10.5   9.288938  1.211062
# 19     14.6  14.093307  0.506693
# 143    10.4   8.690245  1.709755
# 86     12.0  11.661198  0.338802
# 114    14.6  15.718484 -1.118484
# 173    11.7  11.631569  0.068431
# 5       7.2  13.353607 -6.153607
# 126     6.6  11.153147 -4.553147
# 117     9.4   6.336368  3.063632
# 73     11.0   9.761580  1.238420
# 140    10.9   9.419571  1.480429
# 98     25.4  24.255165  1.144835
# 172     7.6   7.695191 -0.095191
# 96     11.7  12.153176 -0.453176

# %%
result_sample = comparing.sample(25)
result_sample
# Out:
#      Actual       pred  residual
# 18     11.3   9.969194  1.330806
# 16     12.5  13.774690 -1.274690
# 174    11.5  13.275471 -1.775471
# 86     12.0  11.661198  0.338802
# 152    16.6  16.156193  0.443807
# 98     25.4  24.255165  1.144835
# 75      8.7  12.777706 -4.077706
# 172     7.6   7.695191 -0.095191
# 170     8.4   7.350285  1.049715
# 177    11.7  12.004544 -0.304544
# 114    14.6  15.718484 -1.118484
# 150    16.1  18.101136 -2.001136
# 55     23.7  21.730090  1.969910
# 164    11.9  10.839388  1.060612
# 76      6.9   4.381906  2.518094
# 96     11.7  12.153176 -0.453176
# 143    10.4   8.690245  1.709755
# 69     22.3  21.196925  1.103075
# 38     10.1  10.170454 -0.070454
# 93     22.2  21.535018  0.664982
# 128    24.7  22.202320  2.497680
# 73     11.0   9.761580  1.238420
# 137    20.8  20.938265 -0.138265
# 24      9.7   8.090814  1.609186
# 197    12.8  12.404863  0.395137

# %%
result_sample.plot(kind="bar", figsize = (15, 9));

# %% [markdown]
# ## Error Metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
R2_score = r2_score(y_test, y_pred)
R2_score
# Out:
# 0.8609466508230368

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.5116692224549084

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 3.7967972367152183

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

rmse
# Out:
# 1.9485372043446383

# %%
sales_mean = df["sales"].mean()
sales_mean
# Out:
# 14.0225

# %%
mae / sales_mean   #MAE göre yaklaşık olarak %11 kayıp var
# Out:
# 0.10780311802138764

# %%
rmse / sales_mean   #RMSE göre yaklaşık olarak %14 kayıp var
# Out:
# 0.13895790367941796

# %% [markdown]
# ## Adjusted R2 Score (Düzenlenmiş R2 Skor)

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)
    n = df.shape[0]   # number of observations gözlem
    p = df.shape[1]-1 # number of independent variables feature
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.8588182832335934

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)
    n = df.shape[0]   # number of observations gözlem
    p = 100 # number of independent variables feature
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)
# Out:
# 0.7204887223614578

# %% [markdown]
# ## What is the concept of punishment for RMSE error metric?

# %%
variables = {"Actual": [1000, 2000, 3000, 4000, 5000], "pred": [1100, 2200, 3200, 4200, 5300]}

variables2 = {"Actual": [1000, 2000, 3000, 4000, 5000], "pred": [1100, 2200, 3200, 4200, 5800]} 
## RMSE'nin hataları nasıl cezalandırdığını görmek için pred'in son değerini 3600 yaptım.

# %%
variables, variables2
# Out:
# ({'Actual': [1000, 2000, 3000, 4000, 5000],
#   'pred': [1100, 2200, 3200, 4200, 5300]},
#  {'Actual': [1000, 2000, 3000, 4000, 5000],
#   'pred': [1100, 2200, 3200, 4200, 5800]})

# %%
df_2 = pd.DataFrame(variables)
df_2
# Out:
#    Actual  pred
# 0    1000  1100
# 1    2000  2200
# 2    3000  3200
# 3    4000  4200
# 4    5000  5300

# %%
df_3 = pd.DataFrame(variables2)
df_3
# Out:
#    Actual  pred
# 0    1000  1100
# 1    2000  2200
# 2    3000  3200
# 3    4000  4200
# 4    5000  5800

# %%
df_2["residual"] = abs(df_2.Actual - df_2.pred)

df_2
# Out:
#    Actual  pred  residual
# 0    1000  1100       100
# 1    2000  2200       200
# 2    3000  3200       200
# 3    4000  4200       200
# 4    5000  5300       300

# %%
df_3["residual"] = abs(df_3.Actual - df_3.pred)

df_3
# Out:
#    Actual  pred  residual
# 0    1000  1100       100
# 1    2000  2200       200
# 2    3000  3200       200
# 3    4000  4200       200
# 4    5000  5800       800

# %%
df_2.residual.sum() / 5 # Residualleri topla gözlem sayısına böl
# Out:
# 200.0

# %%
df_3.residual.sum() / 5
# Out:
# 300.0

# %%
((df_2.residual ** 2).sum() / 5) ** 0.5 # residullerin karsini al topla gözlem sayısına böl ve karakökünü al
# Out:
# 209.76176963403032

# %%
((df_3.residual ** 2).sum() / 5) ** 0.5
# Out:
# 392.42833740697165

# %% [markdown]
# ## Evaluation Model

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance: ")
    print("---------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.8609466508230368
# MAE 		: 1.5116692224549084
# MSE 		: 3.7967972367152183
# RMSE 		: 1.9485372043446383

# %%
y_train_pred = model.predict(X_train)

# %%
eval_metric(y_train,y_train_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.9055159502227753
# MAE 		: 1.1581502948072533
# MSE 		: 2.4793551789057875
# RMSE 		: 1.5745968305905444

# %% [markdown]
# ### Is data suitable for linear regression?

# %% [markdown]
# How can we know whether a data is suitable for linear regression:
# if there is a linear pattern in the distribution, in residual.
# if the residuals has normal distribution.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
residual = y_test - y_pred

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = y_test, y = residual)
plt.axhline(y = 0, color = "r", linestyle = "--");

# %% [markdown]
# https://stats.stackexchange.com/questions/12262/what-if-residuals-are-normally-distributed-but-y-is-not
#
# Linear modele karar vermek icin makale

# %%
sns.kdeplot(residual);

# %% [markdown]
# shows a normal distribution

# %%
stats.probplot(residual,dist = "norm", plot = plt);

# %%
# !pip install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      -------------------------------------- 282.6/282.6 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.0 in c:\users\jawed\anaconda3\lib\site-packages (from yellowbrick) (1.23.5)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\jawed\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\jawed\anaconda3\lib\site-packages (from yellowbrick) (1.2.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\jawed\anaconda3\lib\site-packages (from yellowbrick) (3.7.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\jawed\anaconda3\lib\site-packages (from yellowbrick) (1.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jawed\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jawed\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jawed\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jawed\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jawed\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jawed\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jawed\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jawed\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jawed\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\jawed\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5

# %%
from yellowbrick.regressor import ResidualsPlot

# %% [markdown]
# Residual Plot
#
# https://www.scikit-yb.org/en/latest/api/regressor/residuals.html

# %%
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();                # Finalize and render the figure

# %%
from yellowbrick.regressor import PredictionError

# %%
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show();

# %% [markdown]
# ## Retraining Model on Full Data

# %%
final_model = LinearRegression()
final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
coeff_df = pd.DataFrame(final_model.coef_, index = X.columns, columns = ["Coefficant"])

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
final_model.intercept_
# Out:
# 2.9388893694594085

# %%
coeff_df
# Out:
#            Coefficant
# TV           0.045765
# radio        0.188530
# newspaper   -0.001037

# %% [markdown]
# ## Prediction on New Data

# %%
adv = [[150, 20, 15]]

# %%
final_model.predict(adv)
# Out:
# array([13.55862413])

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
final_model.intercept_
# Out:
# 2.9388893694594085

# %%
sum(final_model.coef_ * [150, 20, 15]) + final_model.intercept_
# Out:
# 13.558624130495996

# %%
adv2 = [[150, 20, 15], [160, 20, 15]]

# %%
final_model.predict(adv2)
# Out:
# array([13.55862413, 14.01627059])

# %%
14.01627059 - 13.55862413
# Out:
# 0.4576464599999994
