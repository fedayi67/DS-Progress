# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Import Library

# %% [markdown]
# ## Read Data Set

# %% [markdown]
# Datanin tanimasina yonelik tum kodlar burada olacak visualization dahil

# %% [markdown]
# ## Model

# %% [markdown]
# ### Splitting the dataset into X (independent variables) and y (dependent variables)

# %% [markdown]
# X = Features
#
# y = Target

# %% [markdown]
# ### Train | Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ### Training the Model (Modeli egitmek)

# %%
from sklearn.linear_model import LinearRegression  # Modeli import et buradaki linear regression

# %%
slr = LinearRegression()

# %%
slr.fit(X_train, y_train)

# %% [markdown]
# ### Predicting Test Data (Tahmin almak)

# %%
y_train_pred = slr.predict(X_train)

y_pred = slr.predict(X_test)

# %% [markdown]
# ### Evaluating the Model (Modeli degerlendir (R2, MAE, MSE, RMSE))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def train_val(y_train, y_train_pred, y_test, y_pred, i):  # train_val: train validation
    scores = {i+"_train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
    i+"_test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %%
slr_score = train_val(y_train, y_train_pred, y_test, y_pred, "s_linear")
slr_score

# %% [markdown]
# ### Residuals Check (Normal dagilim varsa bir pattern yoksa o zaman modelin dogrusalidir). Modelin dogrusal oldugunun kontrolu icin.

# %%
sns.displot((y_test - y_pred), bins = 50, kde = True);

# %% [markdown]
# ### Prediction Error for LinearRegression (tahmin hatalarinin yellow brick kutuphanesi ile tespiti)

# %%
from yellowbrick.regressor import PredictionError

model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();                # Finalize and render the figure

# %% [markdown]
# ### Cross Validate (Capraz dogrulama R2, MAE, MSE, RMSE degerlerim gercekten CV sonrasi aldigim degerle uyumlu mu?)
